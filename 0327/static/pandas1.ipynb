# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
    'name': ['Alice', 'Kim', 'John'],
    'gender': ['F', 'M', 'M'],
    'age': [10, 11, 9],
    'grades': [100, 99, 98]
    }
)

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>gender</th>
#       <th>age</th>
#       <th>grades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alice</td>
#       <td>F</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Kim</td>
#       <td>M</td>
#       <td>11</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>John</td>
#       <td>M</td>
#       <td>9</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
s = pd.Series(['red', 'blue', 'black'])

# %%
s
# Out:
# <pre>0      red
# 1     blue
# 2    black
# dtype: object</pre>

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
df['age']
# Out:
# <pre>0    10
# 1    11
# 2     9
# Name: age, dtype: int64</pre>

# %%
df[['age']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
type(df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['age'].describe()
# Out:
# <pre>count     3.0
# mean     10.0
# std       1.0
# min       9.0
# 25%       9.5
# 50%      10.0
# 75%      10.5
# max      11.0
# Name: age, dtype: float64</pre>

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>grades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>10.0</td>
#       <td>99.0</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>9.0</td>
#       <td>98.0</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>9.5</td>
#       <td>98.5</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>10.0</td>
#       <td>99.0</td>
#     </tr>
#     <tr>
# ...

# %%
df['age'].max()
# Out:
# 11

# %%
inventory = pd.read_csv('Sloan_Inventory.csv')

# %%
inventory.shape
# Out:
# (825, 16)

# %%
inventory.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#       <td>337</td>
# ...

# %%
inventory.head(50)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#       <td>337</td>
# ...

# %%
inventory.tail(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>820</th>
#       <td>Ultrasonic Cleaners</td>
#       <td>490820</td>
#       <td>Model 221 ultrasonic cleaning bath with timer....</td>
#       <td>1</td>
# ...

# %%
inventory.dtypes
# Out:
# <pre>Category            object
# Product Number       int64
# Description         object
# Quantity on-hand     int64
# January              int64
# February             int64
# March                int64
# April                int64
# May                  int64
# June                 int64
# July                 int64
# August               int64
# September            int64
# October              int64
# November             int64
# December             int64
# dtype: object</pre>

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          825 non-null    object
#  1   Product Number    825 non-null    int64
#  2   Description       825 non-null    object
#  3   Quantity on-hand  825 non-null    int64
#  4   January           825 non-null    int64
#  5   February          825 non-null    int64
#  6   March             825 non-null    int64
#  7   April             825 non-null    int64
#  8   May               825 non-null    int64
#  9   June              825 non-null    int64
#  10  July              825 non-null    int64
#  11  August            825 non-null    int64
#  12  September         825 non-null    int64
#  13  October           825 non-null    int64
#  14  November          825 non-null    int64
#  15  December          825 non-null    int64
# dtypes: int64(14), object(2)
# ...

# %%
inventory.shape[1]
# Out:
# 16

# %%
inventory.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Product Number</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>825.00000</td>
#       <td>825.000000</td>
#       <td>825.000000</td>
#       <td>825.000000</td>
#       <td>825.000000</td>
#       <td>825.000000</td>
#       <td>825.000000</td>
# ...

# %%
inventory.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#       <td>337</td>
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 25.4 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
inventory.to_excel('inventory.xlsx', sheet_name='inventory', index=False)

# %%
df = inventory

# %%
df.columns
# Out:
# Index(['Category', 'Product Number', 'Description', 'Quantity on-hand',
#        'January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
df['Description']
# Out:
# <pre>0                    Microtrac particle analyzer (3 pcs)
# 1                                   3300 IR gas analyzer
# 2                     TGA-7 thermogravitmetric analyzer.
# 3           Model 911 Dew-All digital humidity analyzer.
# 4                           1000 tablet? Hardness Tester
#                              ...
# 820    Model 221 ultrasonic cleaning bath with timer....
# 821    Model 75HT Aquasonic stainless steel ultrasoni...
# 822    Model B-22 ultrasonic cleaning bath with 9 1/2...
# 823    Model FS-28 11 quart capacity ultrasonic clean...
# 824    SE-40 ultrasonic cleaner  6" x 6" x 3" deep ch...
# Name: Description, Length: 825, dtype: object</pre>

# %%
df2 = df[['Category', 'Product Number', 'Description']]

# %%
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Analyzer</td>
#       <td>490001</td>
#       <td>3300 IR gas analyzer</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Analyzer</td>
#       <td>490002</td>
#       <td>TGA-7 thermogravitmetric analyzer.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Analyzer</td>
#       <td>490003</td>
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Product Number', 'Description', 'Quantity on-hand',
#        'January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
df[(df['Quantity on-hand'] > 99) | (df['Quantity on-hand'] < 1) ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>Autoclave</td>
#       <td>490035</td>
#       <td>Validar Plus tabletop sterilizer.</td>
#       <td>0</td>
#       <td>514</td>
# ...

# %%
df[(df['Quantity on-hand'] > 95) & (df['January'] > 900)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14</th>
#       <td>Analyzer</td>
#       <td>490014</td>
#       <td>B-641 thermal cycler</td>
#       <td>98</td>
#       <td>917</td>
#       <td>856</td>
# ...

# %%
df[df['Quantity on-hand'].isin([10, 50,80, 90, 70, 100])]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Analyzer</td>
#       <td>490002</td>
#       <td>TGA-7 thermogravitmetric analyzer.</td>
#       <td>90</td>
#       <td>805</td>
# ...

# %% [markdown]
# - df[]: either rows or columns
# - df.loc[]: both rows and columns based on location labels
# - df.iloc[]: both rows and columns based on location index

# %%
df.loc[df['Quantity on-hand'] > 99, ['Category', 'Product Number', 'Description', 'Quantity on-hand','January']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>265</th>
#       <td>Biohood</td>
#       <td>490265</td>
#       <td>4' wide labgard NU 440-400 class IIA2 tabletop...</td>
#       <td>100</td>
#       <td>972</td>
#     </tr>
#     <tr>
#       <th>406</th>
#       <td>Centrifuges</td>
#       <td>490406</td>
#       <td>8R (tabletop refrigerated centrifuge) w/216 ro...</td>
#       <td>100</td>
#       <td>827</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.columns
# Out:
# Index(['Category', 'Product Number', 'Description', 'Quantity on-hand',
#        'January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
df.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#       <td>337</td>
# ...

# %%
# the first two rows
df.iloc[0:2]
df.iloc[:2]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#       <td>337</td>
# ...

# %%
# the third to the fifth
df.iloc[2:5]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Analyzer</td>
#       <td>490002</td>
#       <td>TGA-7 thermogravitmetric analyzer.</td>
#       <td>90</td>
#       <td>805</td>
# ...

# %%
df.iloc[:3, :4]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Analyzer</td>
#       <td>490001</td>
#       <td>3300 IR gas analyzer</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Analyzer</td>
#       <td>490002</td>
#       <td>TGA-7 thermogravitmetric analyzer.</td>
#       <td>90</td>
# ...

# %%
df.iloc[-3:, -4:]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>822</th>
#       <td>864</td>
#       <td>245</td>
#       <td>264</td>
#       <td>234</td>
#     </tr>
#     <tr>
#       <th>823</th>
#       <td>403</td>
#       <td>871</td>
#       <td>188</td>
#       <td>644</td>
#     </tr>
#     <tr>
#       <th>824</th>
#       <td>882</td>
#       <td>877</td>
#       <td>287</td>
#       <td>56</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[::2, :]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyzer</td>
#       <td>490000</td>
#       <td>Microtrac particle analyzer (3 pcs)</td>
#       <td>31</td>
#       <td>337</td>
# ...

# %%
df.iloc[1::2, :]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Product Number</th>
#       <th>Description</th>
#       <th>Quantity on-hand</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Analyzer</td>
#       <td>490001</td>
#       <td>3300 IR gas analyzer</td>
#       <td>68</td>
#       <td>855</td>
#       <td>837</td>
# ...
